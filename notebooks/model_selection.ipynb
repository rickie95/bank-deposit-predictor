# %% [markdown]
# # Training pipeline

# %%
import mlflow

mlflow.set_tracking_uri("http://localhost:5000")
mlflow.set_experiment("bank-deposit")
# Out:
# <Experiment: artifact_location='mlflow-artifacts:/845276055540234593', creation_time=1761777281289, experiment_id='845276055540234593', last_update_time=1761777281289, lifecycle_stage='active', name='bank-deposit', tags={}>

# %%
from dataset import load_dataset
# import random
# random_state = random.randint(0, 10**4)
random_state = 77
print(f"Current random state {random_state}")

MODEL_TYPE_TAG = "model_type"
# Out:
# Current random state 77

# %%
from sklearn.model_selection import train_test_split
X_data, y_data = load_dataset("../data/train.csv")
X_train, X_test, y_train, y_test = train_test_split(
    X_data,
    y_data,
    test_size=0.2,
    stratify=y_data,
    random_state=random_state
)
# Out:
# /home/riccardo/Projects/personale/bank-deposit-predictor/notebooks/dataset.py:11: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   encoded['education'] = encoded['education'].replace({
# /home/riccardo/Projects/personale/bank-deposit-predictor/notebooks/dataset.py:16: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   encoded['housing'] = encoded['housing'].replace({"no": False, "yes": True})
# /home/riccardo/Projects/personale/bank-deposit-predictor/notebooks/dataset.py:17: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   encoded['loan'] = encoded['loan'].replace({"no": False, "yes": True})
# /home/riccardo/Projects/personale/bank-deposit-predictor/notebooks/dataset.py:18: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   encoded['default'] = encoded['default'].replace({"no": False, "yes": True})

# %% [markdown]
# ## Logistic Regression

# %% [markdown]
# Vanilla, simple CV

# %%
from datetime import datetime
from pathlib import Path
import joblib
from sklearn.model_selection import GridSearchCV, StratifiedKFold
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (
    f1_score, precision_score, recall_score, accuracy_score
)

mlflow.sklearn.autolog(log_models=True)

linear_regression_models_path = Path("../models/linear_regression/")
linear_regression_models_path.mkdir(exist_ok=True, parents=True)

str_time = datetime.today().strftime("%Y-%m-%d %H:%M:%S")

tags = {MODEL_TYPE_TAG: "xgboost"}

with mlflow.start_run(run_name=f"Logistic Regression {str_time}", tags=tags) as current_run:
    param = {
        'C':[0.01,0.1,1,10],
        'penalty':['l1','l2'],
        'solver':['liblinear']
    }

    log_reg = LogisticRegression(intercept_scaling=True, dual=False, fit_intercept=True)

    cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=random_state)
    grid = GridSearchCV(log_reg, param_grid=param, scoring='roc_auc', cv=cv, n_jobs=-1)
    grid.fit(X_train, y_train)
    print(grid.best_score_, grid.best_params_)

    model_name = f"{current_run.info.run_name}.joblib"
    model_path = str(linear_regression_models_path / model_name)

    joblib.dump(grid, model_path)

    mlflow.sklearn.log_model(
        sk_model=grid,
        name=current_run.info.run_name
    )

    preds = grid.predict(X_test)

    acc = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds)
    pre = precision_score(y_test, preds)
    recall = recall_score(y_test, preds)

    print(f"Accuracy:  {acc:.4f}")
    print(f"Precision: {pre:.4f}")
    print(f"Recall:    {recall:.4f}")
    print(f"F1:        {f1:.4f}")

    mlflow.log_metrics({
        "test_accuracy": float(acc),
        "test_precision": float(pre),
        "test_recall": float(recall),
        "test_f1": float(f1)
    })
# Out:
# 2025/10/30 21:45:08 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/home/riccardo/Projects/personale/bank-deposit-predictor/.venv/lib/python3.12/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2025/10/30 21:46:37 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/home/riccardo/Projects/personale/bank-deposit-predictor/.venv/lib/python3.12/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2025/10/30 21:46:39 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be added to conda.yaml environment spec without a version specifier.
# 2025/10/30 21:46:44 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be added to conda.yaml environment spec without a version specifier.
# 2025/10/30 21:46:44 INFO mlflow.sklearn.utils: Logging the 5 best runs, 3 runs will be omitted.
# 2025/10/30 21:46:46 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/home/riccardo/Projects/personale/bank-deposit-predictor/.venv/lib/python3.12/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 🏃 View run learned-boar-497 at: http://localhost:5000/#/experiments/845276055540234593/runs/b071d2f8329646afbb1307e5ecd412ce
# 🧪 View experiment at: http://localhost:5000/#/experiments/845276055540234593
# 🏃 View run intelligent-toad-852 at: http://localhost:5000/#/experiments/845276055540234593/runs/5410d96eb1b44137b163f46988aec316
# 🧪 View experiment at: http://localhost:5000/#/experiments/845276055540234593
# 🏃 View run gifted-crow-878 at: http://localhost:5000/#/experiments/845276055540234593/runs/def4e8a768c4435fbfe58a9164459690
# 🧪 View experiment at: http://localhost:5000/#/experiments/845276055540234593
# 🏃 View run puzzled-roo-716 at: http://localhost:5000/#/experiments/845276055540234593/runs/8741b10dd4a644fcaa9d33a346e84591
# 🧪 View experiment at: http://localhost:5000/#/experiments/845276055540234593
# 🏃 View run resilient-sow-87 at: http://localhost:5000/#/experiments/845276055540234593/runs/083329150caf4f2eb8888a329df7f114
# 🧪 View experiment at: http://localhost:5000/#/experiments/845276055540234593
# 0.9235008158410576 {'C': 0.01, 'penalty': 'l1', 'solver': 'liblinear'}
# 2025/10/30 21:46:48 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be added to conda.yaml environment spec without a version specifier.
# 2025/10/30 21:46:48 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/10/30 21:46:49 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/home/riccardo/Projects/personale/bank-deposit-predictor/.venv/lib/python3.12/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 🏃 View run loud-shad-432 at: http://localhost:5000/#/experiments/845276055540234593/runs/f963eb51144d42948424990b5b2bfdfa
# 🧪 View experiment at: http://localhost:5000/#/experiments/845276055540234593

# %% [markdown]
# ## Logistic regression with balanced weights

# %%
from datetime import datetime
from pathlib import Path
import joblib
from sklearn.model_selection import GridSearchCV, StratifiedKFold
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (
    f1_score, precision_score, recall_score, accuracy_score
)

mlflow.sklearn.autolog(log_models=True)

linear_regression_models_path = Path("../models/linear_regression_balanced/")
linear_regression_models_path.mkdir(exist_ok=True, parents=True)

str_time = datetime.today().strftime("%Y-%m-%d %H:%M:%S")

tags = {MODEL_TYPE_TAG: "xgboost"}

with mlflow.start_run(run_name=f"Logistic Regression Weighted {str_time}", tags=tags) as current_run:
    param = {
        'C':[0.01,0.1,1,10],
        'penalty':['l1','l2'],
        'solver':['liblinear']
    }

    log_reg = LogisticRegression(
        intercept_scaling=True,
        dual=False,
        fit_intercept=True,
        class_weight='balanced'
    )

    cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=random_state)
    grid = GridSearchCV(log_reg, param_grid=param, scoring='roc_auc', cv=cv, n_jobs=-1)
    grid.fit(X_train, y_train)
    print(grid.best_score_, grid.best_params_)

    model_name = f"{current_run.info.run_name}.joblib"
    model_path = str(linear_regression_models_path / model_name)

    joblib.dump(grid, model_path)

    mlflow.sklearn.log_model(
        sk_model=grid,
        name=current_run.info.run_name
    )

    preds = grid.predict(X_test)

    acc = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds)
    pre = precision_score(y_test, preds)
    recall = recall_score(y_test, preds)

    print(f"Accuracy:  {acc:.4f}")
    print(f"Precision: {pre:.4f}")
    print(f"Recall:    {recall:.4f}")
    print(f"F1:        {f1:.4f}")

    mlflow.log_metrics({
        "test_accuracy": float(acc),
        "test_precision": float(pre),
        "test_recall": float(recall),
        "test_f1": float(f1)
    })
# Out:
# 2025/10/30 21:56:02 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/home/riccardo/Projects/personale/bank-deposit-predictor/.venv/lib/python3.12/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2025/10/30 21:57:27 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/home/riccardo/Projects/personale/bank-deposit-predictor/.venv/lib/python3.12/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2025/10/30 21:57:29 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be added to conda.yaml environment spec without a version specifier.
# 2025/10/30 21:57:34 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be added to conda.yaml environment spec without a version specifier.
# 2025/10/30 21:57:34 INFO mlflow.sklearn.utils: Logging the 5 best runs, 3 runs will be omitted.
# 2025/10/30 21:57:36 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/home/riccardo/Projects/personale/bank-deposit-predictor/.venv/lib/python3.12/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 🏃 View run efficient-doe-270 at: http://localhost:5000/#/experiments/845276055540234593/runs/0d66396326a54aafa6761e9612eb547a
# 🧪 View experiment at: http://localhost:5000/#/experiments/845276055540234593
# 🏃 View run likeable-doe-573 at: http://localhost:5000/#/experiments/845276055540234593/runs/c220abd57c6a4835bb0053fa1a4c06b6
# 🧪 View experiment at: http://localhost:5000/#/experiments/845276055540234593
# 🏃 View run charming-quail-609 at: http://localhost:5000/#/experiments/845276055540234593/runs/dadda85c4b03403dbc06f0f0693acbba
# 🧪 View experiment at: http://localhost:5000/#/experiments/845276055540234593
# 🏃 View run colorful-frog-112 at: http://localhost:5000/#/experiments/845276055540234593/runs/ce78cf247dc8468ab5924ea0816cb6d3
# 🧪 View experiment at: http://localhost:5000/#/experiments/845276055540234593
# 🏃 View run merciful-yak-713 at: http://localhost:5000/#/experiments/845276055540234593/runs/ddbc0280284445af91218d706b2186dc
# 🧪 View experiment at: http://localhost:5000/#/experiments/845276055540234593
# 0.9250638118015624 {'C': 0.1, 'penalty': 'l1', 'solver': 'liblinear'}
# 2025/10/30 21:57:38 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be added to conda.yaml environment spec without a version specifier.
# 2025/10/30 21:57:38 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/10/30 21:57:39 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/home/riccardo/Projects/personale/bank-deposit-predictor/.venv/lib/python3.12/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 🏃 View run caring-skunk-511 at: http://localhost:5000/#/experiments/845276055540234593/runs/0c29e9b19de04fb997e8ea1e722418a4
# 🧪 View experiment at: http://localhost:5000/#/experiments/845276055540234593

# %% [markdown]
# ## XGBoost

# %%
from datetime import datetime

from xgboost import XGBClassifier
from sklearn.metrics import (
    f1_score, precision_score, recall_score, accuracy_score,
    confusion_matrix
)

mlflow.xgboost.autolog(log_models=True)

str_time = datetime.today().strftime("%Y-%m-%d %H:%M:%S")

tags = {MODEL_TYPE_TAG: "xgboost"}

with mlflow.start_run(run_name=f"XGBoost {str_time}", tags=tags):
    bst = XGBClassifier(
        n_estimators=100,
        max_depth=5,
        learning_rate=0.05,
        objective='binary:logistic',
        n_jobs=8,
        random_state=random_state,
        eval_metric=["logloss", "auc"]
    )

    bst.fit(
        X_train,
        y_train,
        eval_set=[(X_train, y_train), (X_test, y_test)]
    )

    print("Logging model...")
    mlflow.xgboost.log_model(xgb_model=bst, name="model_json", model_format="json")

    preds = bst.predict(X_test)

    acc = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds)
    pre = precision_score(y_test, preds)
    recall = recall_score(y_test, preds)

    print(f"Accuracy:  {acc:.4f}")
    print(f"Precision: {pre:.4f}")
    print(f"Recall:    {recall:.4f}")
    print(f"F1:        {f1:.4f}")

    mlflow.log_metrics({
        "test_accuracy": float(acc),
        "test_precision": float(pre),
        "test_recall": float(recall),
        "test_f1": float(f1)
    })

    cm = confusion_matrix(y_test, preds)
    print("Confusion matrix:\n", cm)
# Out:
# [0]	validation_0-logloss:0.34762	validation_0-auc:0.92708	validation_1-logloss:0.34762	validation_1-auc:0.92610
# [1]	validation_0-logloss:0.33185	validation_0-auc:0.93004	validation_1-logloss:0.33187	validation_1-auc:0.92905
# [2]	validation_0-logloss:0.31874	validation_0-auc:0.93134	validation_1-logloss:0.31881	validation_1-auc:0.93032
# [3]	validation_0-logloss:0.30757	validation_0-auc:0.93210	validation_1-logloss:0.30766	validation_1-auc:0.93108
# [4]	validation_0-logloss:0.29780	validation_0-auc:0.93412	validation_1-logloss:0.29795	validation_1-auc:0.93307
# [5]	validation_0-logloss:0.28917	validation_0-auc:0.93472	validation_1-logloss:0.28937	validation_1-auc:0.93367
# [6]	validation_0-logloss:0.28149	validation_0-auc:0.93555	validation_1-logloss:0.28172	validation_1-auc:0.93432
# [7]	validation_0-logloss:0.27454	validation_0-auc:0.93581	validation_1-logloss:0.27481	validation_1-auc:0.93471
# [8]	validation_0-logloss:0.26832	validation_0-auc:0.93689	validation_1-logloss:0.26860	validation_1-auc:0.93573
# [9]	validation_0-logloss:0.26237	validation_0-auc:0.93735	validation_1-logloss:0.26267	validation_1-auc:0.93619
# [10]	validation_0-logloss:0.25719	validation_0-auc:0.93798	validation_1-logloss:0.25751	validation_1-auc:0.93688
# [11]	validation_0-logloss:0.25248	validation_0-auc:0.93818	validation_1-logloss:0.25285	validation_1-auc:0.93706
# [12]	validation_0-logloss:0.24807	validation_0-auc:0.93850	validation_1-logloss:0.24847	validation_1-auc:0.93738
# [13]	validation_0-logloss:0.24380	validation_0-auc:0.93888	validation_1-logloss:0.24421	validation_1-auc:0.93777
# [14]	validation_0-logloss:0.24008	validation_0-auc:0.93912	validation_1-logloss:0.24049	validation_1-auc:0.93805
# [15]	validation_0-logloss:0.23641	validation_0-auc:0.93940	validation_1-logloss:0.23683	validation_1-auc:0.93834
# [16]	validation_0-logloss:0.23315	validation_0-auc:0.93987	validation_1-logloss:0.23359	validation_1-auc:0.93885
# [17]	validation_0-logloss:0.23014	validation_0-auc:0.94031	validation_1-logloss:0.23059	validation_1-auc:0.93939
# [18]	validation_0-logloss:0.22733	validation_0-auc:0.94231	validation_1-logloss:0.22783	validation_1-auc:0.94119
# [19]	validation_0-logloss:0.22447	validation_0-auc:0.94259	validation_1-logloss:0.22498	validation_1-auc:0.94156
# [20]	validation_0-logloss:0.22202	validation_0-auc:0.94287	validation_1-logloss:0.22253	validation_1-auc:0.94180
# [21]	validation_0-logloss:0.21974	validation_0-auc:0.94310	validation_1-logloss:0.22026	validation_1-auc:0.94209
# [22]	validation_0-logloss:0.21740	validation_0-auc:0.94338	validation_1-logloss:0.21792	validation_1-auc:0.94227
# [23]	validation_0-logloss:0.21541	validation_0-auc:0.94361	validation_1-logloss:0.21594	validation_1-auc:0.94251
# [24]	validation_0-logloss:0.21334	validation_0-auc:0.94370	validation_1-logloss:0.21388	validation_1-auc:0.94265
# [25]	validation_0-logloss:0.21143	validation_0-auc:0.94387	validation_1-logloss:0.21198	validation_1-auc:0.94279
# [26]	validation_0-logloss:0.20974	validation_0-auc:0.94411	validation_1-logloss:0.21031	validation_1-auc:0.94305
# [27]	validation_0-logloss:0.20814	validation_0-auc:0.94433	validation_1-logloss:0.20872	validation_1-auc:0.94327
# [28]	validation_0-logloss:0.20668	validation_0-auc:0.94444	validation_1-logloss:0.20725	validation_1-auc:0.94342
# [29]	validation_0-logloss:0.20515	validation_0-auc:0.94456	validation_1-logloss:0.20572	validation_1-auc:0.94355
# [30]	validation_0-logloss:0.20382	validation_0-auc:0.94481	validation_1-logloss:0.20439	validation_1-auc:0.94382
# [31]	validation_0-logloss:0.20241	validation_0-auc:0.94501	validation_1-logloss:0.20298	validation_1-auc:0.94401
# [32]	validation_0-logloss:0.20121	validation_0-auc:0.94511	validation_1-logloss:0.20181	validation_1-auc:0.94411
# [33]	validation_0-logloss:0.20011	validation_0-auc:0.94521	validation_1-logloss:0.20071	validation_1-auc:0.94424
# [34]	validation_0-logloss:0.19902	validation_0-auc:0.94544	validation_1-logloss:0.19963	validation_1-auc:0.94444
# [35]	validation_0-logloss:0.19798	validation_0-auc:0.94560	validation_1-logloss:0.19860	validation_1-auc:0.94462
# [36]	validation_0-logloss:0.19691	validation_0-auc:0.94575	validation_1-logloss:0.19754	validation_1-auc:0.94477
# [37]	validation_0-logloss:0.19602	validation_0-auc:0.94591	validation_1-logloss:0.19665	validation_1-auc:0.94499
# [38]	validation_0-logloss:0.19516	validation_0-auc:0.94605	validation_1-logloss:0.19580	validation_1-auc:0.94518
# [39]	validation_0-logloss:0.19428	validation_0-auc:0.94628	validation_1-logloss:0.19492	validation_1-auc:0.94539
# [40]	validation_0-logloss:0.19349	validation_0-auc:0.94641	validation_1-logloss:0.19414	validation_1-auc:0.94549
# [41]	validation_0-logloss:0.19276	validation_0-auc:0.94650	validation_1-logloss:0.19341	validation_1-auc:0.94562
# [42]	validation_0-logloss:0.19201	validation_0-auc:0.94663	validation_1-logloss:0.19269	validation_1-auc:0.94573
# [43]	validation_0-logloss:0.19134	validation_0-auc:0.94676	validation_1-logloss:0.19201	validation_1-auc:0.94587
# [44]	validation_0-logloss:0.19069	validation_0-auc:0.94695	validation_1-logloss:0.19138	validation_1-auc:0.94607
# [45]	validation_0-logloss:0.19007	validation_0-auc:0.94704	validation_1-logloss:0.19077	validation_1-auc:0.94615
# [46]	validation_0-logloss:0.18939	validation_0-auc:0.94715	validation_1-logloss:0.19011	validation_1-auc:0.94625
# [47]	validation_0-logloss:0.18887	validation_0-auc:0.94728	validation_1-logloss:0.18958	validation_1-auc:0.94641
# [48]	validation_0-logloss:0.18835	validation_0-auc:0.94737	validation_1-logloss:0.18907	validation_1-auc:0.94651
# [49]	validation_0-logloss:0.18783	validation_0-auc:0.94745	validation_1-logloss:0.18856	validation_1-auc:0.94657
# [50]	validation_0-logloss:0.18738	validation_0-auc:0.94756	validation_1-logloss:0.18812	validation_1-auc:0.94667
# [51]	validation_0-logloss:0.18695	validation_0-auc:0.94764	validation_1-logloss:0.18768	validation_1-auc:0.94678
# [52]	validation_0-logloss:0.18648	validation_0-auc:0.94774	validation_1-logloss:0.18722	validation_1-auc:0.94687
# [53]	validation_0-logloss:0.18604	validation_0-auc:0.94783	validation_1-logloss:0.18680	validation_1-auc:0.94697
# [54]	validation_0-logloss:0.18561	validation_0-auc:0.94794	validation_1-logloss:0.18638	validation_1-auc:0.94709
# [55]	validation_0-logloss:0.18524	validation_0-auc:0.94805	validation_1-logloss:0.18600	validation_1-auc:0.94722
# [56]	validation_0-logloss:0.18484	validation_0-auc:0.94816	validation_1-logloss:0.18562	validation_1-auc:0.94733
# [57]	validation_0-logloss:0.18443	validation_0-auc:0.94825	validation_1-logloss:0.18522	validation_1-auc:0.94741
# [58]	validation_0-logloss:0.18410	validation_0-auc:0.94834	validation_1-logloss:0.18490	validation_1-auc:0.94749
# [59]	validation_0-logloss:0.18375	validation_0-auc:0.94842	validation_1-logloss:0.18455	validation_1-auc:0.94758
# [60]	validation_0-logloss:0.18339	validation_0-auc:0.94851	validation_1-logloss:0.18420	validation_1-auc:0.94767
# [61]	validation_0-logloss:0.18310	validation_0-auc:0.94859	validation_1-logloss:0.18391	validation_1-auc:0.94777
# [62]	validation_0-logloss:0.18280	validation_0-auc:0.94866	validation_1-logloss:0.18362	validation_1-auc:0.94783
# [63]	validation_0-logloss:0.18250	validation_0-auc:0.94875	validation_1-logloss:0.18332	validation_1-auc:0.94792
# [64]	validation_0-logloss:0.18222	validation_0-auc:0.94880	validation_1-logloss:0.18305	validation_1-auc:0.94797
# [65]	validation_0-logloss:0.18189	validation_0-auc:0.94894	validation_1-logloss:0.18273	validation_1-auc:0.94810
# [66]	validation_0-logloss:0.18166	validation_0-auc:0.94900	validation_1-logloss:0.18249	validation_1-auc:0.94819
# [67]	validation_0-logloss:0.18142	validation_0-auc:0.94906	validation_1-logloss:0.18225	validation_1-auc:0.94825
# [68]	validation_0-logloss:0.18120	validation_0-auc:0.94913	validation_1-logloss:0.18202	validation_1-auc:0.94834
# [69]	validation_0-logloss:0.18093	validation_0-auc:0.94920	validation_1-logloss:0.18176	validation_1-auc:0.94840
# [70]	validation_0-logloss:0.18073	validation_0-auc:0.94924	validation_1-logloss:0.18157	validation_1-auc:0.94846
# [71]	validation_0-logloss:0.18054	validation_0-auc:0.94931	validation_1-logloss:0.18139	validation_1-auc:0.94853
# [72]	validation_0-logloss:0.18026	validation_0-auc:0.94943	validation_1-logloss:0.18111	validation_1-auc:0.94864
# [73]	validation_0-logloss:0.18005	validation_0-auc:0.94948	validation_1-logloss:0.18090	validation_1-auc:0.94871
# [74]	validation_0-logloss:0.17982	validation_0-auc:0.94956	validation_1-logloss:0.18068	validation_1-auc:0.94877
# [75]	validation_0-logloss:0.17963	validation_0-auc:0.94963	validation_1-logloss:0.18051	validation_1-auc:0.94883
# [76]	validation_0-logloss:0.17943	validation_0-auc:0.94970	validation_1-logloss:0.18031	validation_1-auc:0.94890
# [77]	validation_0-logloss:0.17926	validation_0-auc:0.94975	validation_1-logloss:0.18015	validation_1-auc:0.94896
# [78]	validation_0-logloss:0.17909	validation_0-auc:0.94979	validation_1-logloss:0.17999	validation_1-auc:0.94899
# [79]	validation_0-logloss:0.17890	validation_0-auc:0.94988	validation_1-logloss:0.17981	validation_1-auc:0.94908
# [80]	validation_0-logloss:0.17874	validation_0-auc:0.94993	validation_1-logloss:0.17965	validation_1-auc:0.94913
# [81]	validation_0-logloss:0.17861	validation_0-auc:0.94998	validation_1-logloss:0.17952	validation_1-auc:0.94918
# [82]	validation_0-logloss:0.17844	validation_0-auc:0.95006	validation_1-logloss:0.17935	validation_1-auc:0.94926
# [83]	validation_0-logloss:0.17822	validation_0-auc:0.95015	validation_1-logloss:0.17915	validation_1-auc:0.94934
# [84]	validation_0-logloss:0.17806	validation_0-auc:0.95022	validation_1-logloss:0.17898	validation_1-auc:0.94941
# [85]	validation_0-logloss:0.17790	validation_0-auc:0.95029	validation_1-logloss:0.17883	validation_1-auc:0.94947
# [86]	validation_0-logloss:0.17780	validation_0-auc:0.95034	validation_1-logloss:0.17874	validation_1-auc:0.94952
# [87]	validation_0-logloss:0.17758	validation_0-auc:0.95043	validation_1-logloss:0.17854	validation_1-auc:0.94959
# [88]	validation_0-logloss:0.17742	validation_0-auc:0.95050	validation_1-logloss:0.17840	validation_1-auc:0.94967
# [89]	validation_0-logloss:0.17727	validation_0-auc:0.95056	validation_1-logloss:0.17825	validation_1-auc:0.94973
# [90]	validation_0-logloss:0.17704	validation_0-auc:0.95068	validation_1-logloss:0.17803	validation_1-auc:0.94984
# [91]	validation_0-logloss:0.17688	validation_0-auc:0.95075	validation_1-logloss:0.17788	validation_1-auc:0.94991
# [92]	validation_0-logloss:0.17675	validation_0-auc:0.95080	validation_1-logloss:0.17775	validation_1-auc:0.94995
# [93]	validation_0-logloss:0.17664	validation_0-auc:0.95085	validation_1-logloss:0.17766	validation_1-auc:0.95000
# [94]	validation_0-logloss:0.17654	validation_0-auc:0.95089	validation_1-logloss:0.17757	validation_1-auc:0.95004
# [95]	validation_0-logloss:0.17644	validation_0-auc:0.95094	validation_1-logloss:0.17748	validation_1-auc:0.95007
# [96]	validation_0-logloss:0.17623	validation_0-auc:0.95105	validation_1-logloss:0.17727	validation_1-auc:0.95018
# [97]	validation_0-logloss:0.17606	validation_0-auc:0.95112	validation_1-logloss:0.17712	validation_1-auc:0.95024
# [98]	validation_0-logloss:0.17596	validation_0-auc:0.95116	validation_1-logloss:0.17704	validation_1-auc:0.95028
# [99]	validation_0-logloss:0.17582	validation_0-auc:0.95124	validation_1-logloss:0.17689	validation_1-auc:0.95036
# 2025/10/30 22:06:41 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/home/riccardo/Projects/personale/bank-deposit-predictor/.venv/lib/python3.12/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2025/10/30 22:06:41 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2025/10/30 22:06:41 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/home/riccardo/Projects/personale/bank-deposit-predictor/.venv/lib/python3.12/site-packages/xgboost/sklearn.py:1115: UserWarning: [22:06:41] WARNING: /workspace/src/c_api/c_api.cc:1575: Saving model in the UBJSON format as default.  You can use a file extension: `json` or `ubj` to choose between formats."
# 2025/10/30 22:06:44 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be added to conda.yaml environment spec without a version specifier.
# Logging model...
# 2025/10/30 22:06:48 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be added to conda.yaml environment spec without a version specifier.
# 2025/10/30 22:06:48 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/10/30 22:06:49 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/home/riccardo/Projects/personale/bank-deposit-predictor/.venv/lib/python3.12/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# Accuracy:  0.9212
# Precision: 0.7209
# Recall:    0.5623
# F1:        0.6318
# Confusion matrix:
#  [[124397   3815]
#  [  7673   9856]]
# 🏃 View run XGBoost 2025-10-30 22:06:34 at: http://localhost:5000/#/experiments/845276055540234593/runs/c4816900ea3146d8afea933a8c6916b7
# 🧪 View experiment at: http://localhost:5000/#/experiments/845276055540234593

# %% [markdown]
# ## Final comparison
# Let's review the results from the tested models:
